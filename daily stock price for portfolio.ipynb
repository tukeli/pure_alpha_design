# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as wb

# %%
Mr_alpha = ['^GSPC','SPY','MKC','LLY','CHD','MRK','SBUX','BLL','SCG','AZO','HRL','NRG','PFE','ORLY','XLNX','AES','RHT','HCA','ABT','UAL','AAP','AMD','^IRX']

alpha_portfolio = pd.DataFrame()

for alpha in (Mr_alpha):
    alpha_portfolio[alpha] = wb.DataReader(alpha,data_source='yahoo',start='2018-6-26',end='2018-12-26')['Adj Close']

# %%
alpha_portfolio.head()
# Out:
#                   ^GSPC         SPY         MKC        LLY        CHD  \
# Date
# 2018-06-26  2723.060059  268.806335  105.234474  84.218239  51.317120
# 2018-06-27  2699.629883  266.579468  104.631943  83.782845  51.902863
# 2018-06-28  2716.310059  268.103638  113.422882  84.594254  52.786442
# 2018-06-29  2718.370117  268.489624  114.667442  84.435936  52.776516
# 2018-07-02  2726.709961  269.063660  114.262466  84.960381  52.558102
#
#                   MRK       SBUX        BLL        SCG         AZO  ...    \
# Date                                                                ...
# 2018-06-26  59.888695  49.764496  35.582649  38.122845  675.349976  ...
# 2018-06-27  59.060196  49.231091  35.104763  36.458004  669.219971  ...
# 2018-06-28  59.474445  47.946976  35.094807  38.152569  678.440002  ...
# 2018-06-29  59.868969  48.253185  35.393486  38.172386  670.929993  ...
# 2018-07-02  59.632256  48.460621  35.602562  38.439953  667.809998  ...
#
# ...

# %%
export_excel = alpha_portfolio.to_excel (r'D:\python learning\F701 project\export_dataframe.xlsx', header=True)
